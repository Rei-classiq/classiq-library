# %%
from classiq import *

# %%
@qfunc
def main(a:Output[QNum]):
    a |= 1

# %%
qprog = synthesize(main)
show(qprog)
# Out:
# Quantum program link: https://platform.classiq.io/circuit/38EHupf6lp0I8PtSfPvc7uajRz8
